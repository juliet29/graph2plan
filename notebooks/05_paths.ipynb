# %%
# %load_ext autoreload
# %autoreload 2
# %tb
# Out:
# No traceback available to show.

# %%
from graph2plan.fourtp.tests import test_degen_cycle
import networkx as nx
from graph2plan.export.export import generate_connectivities, test_generate_connectivites, save_case_and_connectivities

# %%
num = 10
print(f'_{num:02}')
# Out:
# _10

# %%
Gs = test_generate_connectivites()
# Out:
# [(1,), (2,), (3,), (4,), (1, 2), (1, 3), (1, 4), (2, 3), (2, 4), (3, 4), (1, 2, 3), (1, 2, 4), (1, 3, 4), (2, 3, 4), (1, 2, 3, 4)]

# %%
Gs[14].edges
# Out:
# EdgeView([('v_s', 'a'), ('v_s', 'b'), ('a', 'c'), ('a', 'b'), ('a', 'v_e'), ('c', 'v_n'), ('c', 'b'), ('c', 'v_w'), ('c', 'v_e'), ('b', 'v_w')])

# %%
merged_doms, T1, T2 = test_degen_cycle()
# Out:
# ==>> face: deque(['c', 'a', 'b'])
# ==>> face afyer rotate: deque(['c', 'a', 'b'])
# ==>> alpha_node_mapping: {<Alphas.NE: 0>: 'c', <Alphas.SE: 1>: 'a', <Alphas.SW: 2>: 'b', <Alphas.NW: 3>: 'c'}
# ==>> path_pairs: [('NORTH', ['c']), ('EAST', ['c', 'a']), ('SOUTH', ['a', 'b']), ('WEST', ['b', 'c'])]
# ==>> face: deque(['c', 'a', 'b'])
# ==>> face afyer rotate: deque(['c', 'a', 'b'])
# -----Initialization complete---
# 3 7
# >>Biconnection check: Skipping, < 3 vertices in Gk-1, currently have ['v_s', 'v_w']...
# incrementing k from 3 to 4
# incrementing k from 4 to 5
# Multiple potential: ['c', 'v_e']. Choosing c
# incrementing k from 5 to 6
# Time to order the last node..
# -----Canonical ordering complete---
# ==>> after canon G_c.edges: [('c', 'a'), ('c', 'v_n'), ('c', 'v_e'), ('c', 'v_w'), ('c', 'b'), ('a', 'b'), ('a', 'v_e'), ('a', 'v_s'), ('b', 'v_s'), ('b', 'v_w'), ('v_n', 'v_e'), ('v_n', 'v_s'), ('v_n', 'v_w'), ('v_e', 'v_s'), ('v_s', 'v_w')]
# ...

# %%
save_case_and_connectivities("three")

# %%
save_rel_graphs(T1, T2)

# %%
paths = generate_connectivities(T1, T2)
# Out:
# {1: ['v_s', 'a', 'c', 'v_n'], 2: ['v_s', 'b', 'c', 'v_n'], 3: ['v_w', 'c', 'v_e'], 4: ['v_w', 'b', 'a', 'v_e']}

# %%
paths
# Out:
# [(1,),
#  (2,),
#  (3,),
#  (4,),
#  (1, 2),
#  (1, 3),
#  (1, 4),
#  (2, 3),
#  (2, 4),
#  (3, 4),
#  (1, 2, 3),
#  (1, 2, 4),
#  (1, 3, 4),
#  (2, 3, 4),
#  (1, 2, 3, 4)]

# %%
len(paths)
# Out:
# 15

# %%
[i for i in nx.all_simple_paths(T2, "v_w", "v_e" )]
# Out:
# [['v_w', 'c', 'v_e'], ['v_w', 'b', 'a', 'v_e']]

# %%
[i for i in nx.all_simple_paths(T1, "v_s", "v_n" )]
# Out:
# [['v_s', 'a', 'c', 'v_n'], ['v_s', 'b', 'c', 'v_n']]

# %%
[i for i in nx.node_disjoint_paths(T2, "v_w", "v_e" )]
# Out:
# [['v_w', 'c', 'v_e'], ['v_w', 'b', 'a', 'v_e']]

# %%
[i for i in nx.node_disjoint_paths(T1, "v_s", "v_n" )]
# Out:
# [['v_s', 'a', 'c', 'v_n']]

# %%
from random import sample
from itertools import combinations

# %%
lst = [1,2,3,4]
sample(lst, 2)
# Out:
# [2, 3]

# %%
list(range(1,5))
# Out:
# [1, 2, 3, 4]

# %%
[i for i in combinations(lst, 2)]
# Out:
# [(1, 2), (1, 3), (1, 4), (2, 3), (2, 4), (3, 4)]
